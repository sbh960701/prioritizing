# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [2, 3.5]
y = [12.3, 2.6]
systems = ['DS4N6', 'Our System']

plt.bar(x, y, color = ['r', 'b'])
plt.xticks(x, systems)

plt.ylabel('avg of rnaks(%)')
plt.xlim(1, 4.5)
plt.ylim(0, 14)

plt.text(1.8, 12.7, '12.3%')
plt.text(3.4, 3, '2.6%')

plt.show()
